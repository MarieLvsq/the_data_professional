# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

#SHFT+ RIGHT CLICK > Copy as path

# %%
titanic = pd.read_csv("C:\\Users\\Ali Shahaab\\Downloads\\1_titanic_modified_seaborn.csv")

# %%
titanic
# Out:
#      survived  pclass                                               name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         sex   age  sibsp  parch            ticket     fare cabin   class  \
# ...

# %%
# delete unnecessary columns
titanic = titanic.drop(["name", "ticket", "cabin"], axis=1)

# %% [markdown]
# # Question: how many men and women were in Titanic?

# %%
sns.catplot("sex", data=titanic, kind="count")

# %%
sns.countplot(x="sex", data=titanic)

# %% [markdown]
# # Question: how many men and women were in different classes?

# %%
sns.catplot("sex", data=titanic, kind='count')

# %% [markdown]
# # Question: What were the total numbers of passengers in different classes sep by gender?

# %%
sns.catplot("class", data=titanic, hue="sex", kind='count')

# %% [markdown]
# # Question: What were the total numbers of passengers in different classes?

# %%
sns.catplot("class",  data=titanic, kind='count')

# %% [markdown]
# # Question: What were the total numbers of passengers dead or alive?

# %%
sns.countplot("alive", data=titanic)
titanic.alive.value_counts()
# Out:
# no     549
# yes    342
# Name: alive, dtype: int64

# %% [markdown]
# # Question: Where did the passengers embark from?

# %%
sns.catplot("embark_town", data=titanic,  kind="count")

# %% [markdown]
# # Question: What classes had the survivors travelled in?

# %%
sns.catplot("class", hue="survived", data=titanic, kind="count")

# %% [markdown]
# # Question: What classes had the survivors travelled in?

# %%
sns.catplot("class", "survived", data=titanic, kind='point')

# %% [markdown]
# # Question: Which gender on which class survived most?

# %%
sns.catplot("class", "survived", hue='sex', data=titanic, kind='point')

# %% [markdown]
# # Question: Passenger from which port survived most?

# %%
sns.catplot("embark_town", "survived", hue='sex', data=titanic, kind='point')

# %% [markdown]
# # Question: What is the age distribution of passengers?

# %%
sns.distplot(titanic.age.dropna())

# %% [markdown]
# # Question: What is the fare distribution of Titanic?

# %%
sns.distplot(titanic.fare.dropna())

# %% [raw]
# FacetGrid: If we wanted to break down a plot (e.g. the last one) by some categories, we needn’t perform boolean queries, nor groupbys, we can use FacetGrid. For example age distribution of survived (0|1) passengers from different classes.

# %%
g = sns.FacetGrid(titanic, row='survived', col='class')
g.map(sns.distplot, "age")
plt.show()

# %% [markdown]
# # Correlation: Show correlation within different attributes of the dataset?

# %%
sns.heatmap(titanic.corr(), annot=True, fmt=".2f")

# %%
df.corr()

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare   class  \
# 0           0       3    male  22.0      1      0   7.2500   Third
# 1           1       1  female  38.0      1      0  71.2833   First
# 2           1       3  female  26.0      0      0   7.9250   Third
# 3           1       1  female  35.0      1      0  53.1000   First
# 4           0       3    male  35.0      0      0   8.0500   Third
# ..        ...     ...     ...   ...    ...    ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000  Second
# 887         1       1  female  19.0      0      0  30.0000   First
# 888         0       3  female   NaN      1      2  23.4500   Third
# 889         1       1    male  26.0      0      0  30.0000   First
# 890         0       3    male  32.0      0      0   7.7500   Third
#
#      embark_town alive
# 0    Southampton    no
# 1      Cherbourg   yes
# 2    Southampton   yes
# 3    Southampton   yes
# 4    Southampton    no
# ...
